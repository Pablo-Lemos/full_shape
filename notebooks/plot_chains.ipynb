# %%
import getdist
from getdist.mcsamples import loadMCSamples
import getdist.plots as gdplt
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
gdsamples = loadMCSamples('../chains/full_shape_bias', settings={'ignore_rows':0.2})

# %%
p = gdplt.get_subplot_plotter(width_inch=6)
p.triangle_plot(gdsamples, ["omegam", "As", "b1"], filled=True)
p.export('/Users/Pablo/Desktop/corner_fs')
